# %%
import os
import openai

#openai.organization = "YOUR_ORG_ID"
#openai.api_key = os.getenv("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")
openai.api_key = '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'
openai.Model.list()
# Out:
# <OpenAIObject list at 0x1df38fa3630> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %%
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Write a job description for python developer having experience of 2 years"},
      
    ]
)

# %%
print(response['choices'][0]['message']['content'])
# Out:
# Job Title: Python Developer
#
# Job Summary:
# We are seeking an experienced Python Developer to join our team. The successful candidate will have at least 2 years of experience with Python programming and will be responsible for developing, testing, and maintaining software applications. The ideal candidate will be able to work independently, have excellent communication skills, and be able to collaborate with a team.
#
# Responsibilities:
# - Write reusable, testable, and efficient code using Python programming language
# - Develop software solutions to meet customer requirements
# - Contribute to the full software development lifecycle including development, testing, deployment, and support
# - Collaborate with cross-functional teams to identify and solve complex software problems
# - Troubleshoot and debug code in a timely manner
# - Stay up-to-date with emerging trends and technologies
#
# Requirements:
# - At least 2 years of experience in Python programming
# ...

# %%
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "I am statrting bakery business. Give me some tips and ideas to boast my business"},
      
    ]
)

# %%
print(response['choices'][0]['message']['content'])
# Out:
# Great! Starting a bakery business can be really exciting. Here are a few tips and ideas to help you boost your bakery business:
#
# 1. Develop a strong brand identity: This means creating a logo, packaging and a brand message that reflects the values you want your bakery to represent. Make sure all these elements work together to create a consistent brand image and message.
#
# 2. Offer unique products: Stand out from the competition by offering unique products that people can't get anywhere else. You can specialize in gluten-free, vegan or organic baked goods, for example, or offer unique flavor combinations that set you apart.
#
# 3. Focus on quality: Nothing beats a quality product when it comes to winning and retaining customers. Make sure all your baked goods are made with the freshest, highest-quality ingredients, and that they are consistently well-made.
#
# ...
